# %% [markdown]
# # How to use AI at the Gym to optimize Santizier Bottle Placement (cuz u lazy)

# %% [markdown]
# Code:
# * https://github.com/kevinkurek/YouTube
# * !conda install -c conda-forge ffmpeg
#
# Original Centriod Animation Files:
# * https://github.com/nrsyed/examples/blob/master/animKMeans2D.py

# %% [markdown]
# ![image.png](attachment:f59154c3-ef0f-4f17-9d65-b1d4dbe7e7a8.png)

# %% [markdown]
# ![image.png](attachment:57f14bf6-e29e-4f87-b95e-5dd27bcd43f3.png)

# %% [markdown]
# ![SegmentLocal](TopFreeWeights.gif "segment")

# %% [markdown]
# ![image.png](attachment:84ebac03-3d74-452e-bb42-d06adf2f0a5e.png)

# %% [markdown]
# ![SegmentLocal](BottlesGIF.gif "segment")
